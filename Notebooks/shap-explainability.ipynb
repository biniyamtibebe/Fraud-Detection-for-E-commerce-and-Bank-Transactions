# %%
import shap
import pandas as pd
import matplotlib.pyplot as plt

X_sample = X_test.sample(200, random_state=42)
X_trans = rf.named_steps['prep'].transform(X_sample)

plainer = shap.TreeExplainer(rf.named_steps['clf'])
shap_values = explainer.shap_values(X_traexns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 5 X_sample = X_test.sample(200, random_state=42)
#       6 X_trans = rf.named_steps['prep'].transform(X_sample)
#       8 plainer = shap.TreeExplainer(rf.named_steps['clf'])
#
# NameError: name 'X_test' is not defined
